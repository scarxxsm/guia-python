# %% [markdown]
# Hola esta es una prueba de **jupyter**

# %%
edad = 18

if edad < 13:
    print("Eres un niño.")
elif edad < 18:
    print("Eres un adolescente.")
else:
    print("Eres mayor de edad.")
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/oscar/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall'
