# %% [markdown]
# Hola esta es una prueba de **jupyter**

# %%
edad = 18

if edad < 13:
    print("Eres un niño.")
elif edad < 18:
    print("Eres un adolescente.")
else:
    print("Eres mayor de edad.")
# Out:
# Eres mayor de edad.
